# %%
import requests
import os
import pandas as pd
from bs4 import BeautifulSoup

def base_interest():
    """
    기준금리를 크롤링하는 함수입니다.
    """

    url = 'http://www.bok.or.kr/portal/singl/baseRate/list.do?dataSeCd=01&menuNo=200643'

    response = requests.get(url)
    response.status_code

    soup = BeautifulSoup(response.text, 'html.parser')

    # results = soup.select('.fixed tbody td')

    fixed_table = soup.select_one('.fixed')
    tr_tags = fixed_table.select('tr')[1:]

    interest_results = []


    for tr_tag in tr_tags:
        year = tr_tag.select('td')[0].text.strip()
        date = tr_tag.select('td')[1].text.strip()
        interest = float(tr_tag.select('td')[2].text.strip())
        
               


        temp={
            '연도': year,
            '날짜': date,
            '기준금리': interest,
        }
        
        interest_results.append(temp)

        
    


    # 데이터프레임 생성
    interest_df = pd.DataFrame(interest_results)
    interest_df


    # 파일 생성
    file_name = 'interest.csv'

    


    interest_df.to_csv(file_name, encoding='utf-8-sig', index=False)
    print("기준금리 파일이 생성되었습니다.")


    return interest_results

# %%
base_interest()
# Out:
# 기준금리 파일이 생성되었습니다.
# [{'연도': '2022', '날짜': '10월 12일', '기준금리': 3.0},
#  {'연도': '2022', '날짜': '08월 25일', '기준금리': 2.5},
#  {'연도': '2022', '날짜': '07월 13일', '기준금리': 2.25},
#  {'연도': '2022', '날짜': '05월 26일', '기준금리': 1.75},
#  {'연도': '2022', '날짜': '04월 14일', '기준금리': 1.5},
#  {'연도': '2022', '날짜': '01월 14일', '기준금리': 1.25},
#  {'연도': '2021', '날짜': '11월 25일', '기준금리': 1.0},
#  {'연도': '2021', '날짜': '08월 26일', '기준금리': 0.75},
#  {'연도': '2020', '날짜': '05월 28일', '기준금리': 0.5},
#  {'연도': '2020', '날짜': '03월 17일', '기준금리': 0.75},
#  {'연도': '2019', '날짜': '10월 16일', '기준금리': 1.25},
#  {'연도': '2019', '날짜': '07월 18일', '기준금리': 1.5},
#  {'연도': '2018', '날짜': '11월 30일', '기준금리': 1.75},
#  {'연도': '2017', '날짜': '11월 30일', '기준금리': 1.5},
#  {'연도': '2016', '날짜': '06월 09일', '기준금리': 1.25},
#  {'연도': '2015', '날짜': '06월 11일', '기준금리': 1.5},
#  {'연도': '2015', '날짜': '03월 12일', '기준금리': 1.75},
#  {'연도': '2014', '날짜': '10월 15일', '기준금리': 2.0},
#  {'연도': '2014', '날짜': '08월 14일', '기준금리': 2.25},
#  {'연도': '2013', '날짜': '05월 09일', '기준금리': 2.5},
#  {'연도': '2012', '날짜': '10월 11일', '기준금리': 2.75},
#  {'연도': '2012', '날짜': '07월 12일', '기준금리': 3.0},
#  {'연도': '2011', '날짜': '06월 10일', '기준금리': 3.25},
#  {'연도': '2011', '날짜': '03월 10일', '기준금리': 3.0},
#  {'연도': '2011', '날짜': '01월 13일', '기준금리': 2.75},
#  {'연도': '2010', '날짜': '11월 16일', '기준금리': 2.5},
#  {'연도': '2010', '날짜': '07월 09일', '기준금리': 2.25},
#  {'연도': '2009', '날짜': '02월 12일', '기준금리': 2.0},
#  {'연도': '2009', '날짜': '01월 09일', '기준금리': 2.5},
#  {'연도': '2008', '날짜': '12월 11일', '기준금리': 3.0},
#  {'연도': '2008', '날짜': '11월 07일', '기준금리': 4.0},
#  {'연도': '2008', '날짜': '10월 27일', '기준금리': 4.25},
#  {'연도': '2008', '날짜': '10월 09일', '기준금리': 5.0},
#  {'연도': '2008', '날짜': '08월 07일', '기준금리': 5.25},
#  {'연도': '2007', '날짜': '08월 09일', '기준금리': 5.0},
#  {'연도': '2007', '날짜': '07월 12일', '기준금리': 4.75},
#  {'연도': '2006', '날짜': '08월 10일', '기준금리': 4.5},
#  {'연도': '2006', '날짜': '06월 08일', '기준금리': 4.25},
#  {'연도': '2006', '날짜': '02월 09일', '기준금리': 4.0},
#  {'연도': '2005', '날짜': '12월 08일', '기준금리': 3.75},
#  {'연도': '2005', '날짜': '10월 11일', '기준금리': 3.5},
#  {'연도': '2004', '날짜': '11월 11일', '기준금리': 3.25},
#  {'연도': '2004', '날짜': '08월 12일', '기준금리': 3.5},
#  {'연도': '2003', '날짜': '07월 10일', '기준금리': 3.75},
#  {'연도': '2003', '날짜': '05월 13일', '기준금리': 4.0},
#  {'연도': '2002', '날짜': '05월 07일', '기준금리': 4.25},
#  {'연도': '2001', '날짜': '09월 19일', '기준금리': 4.0},
#  {'연도': '2001', '날짜': '08월 09일', '기준금리': 4.5},
#  {'연도': '2001', '날짜': '07월 05일', '기준금리': 4.75},
#  {'연도': '2001', '날짜': '02월 08일', '기준금리': 5.0},
#  {'연도': '2000', '날짜': '10월 05일', '기준금리': 5.25},
#  {'연도': '2000', '날짜': '02월 10일', '기준금리': 5.0},
#  {'연도': '1999', '날짜': '05월 06일', '기준금리': 4.75}]
